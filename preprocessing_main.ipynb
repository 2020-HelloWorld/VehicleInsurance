# %%
import pandas as pd
import numpy as np
from difflib import SequenceMatcher

# %%
xls = pd.ExcelFile('Dataset/Training Set (1).xlsx')
df1 = pd.read_excel(xls, 'training_1')
df2 = pd.read_excel(xls, 'training_2')
t=pd.ExcelFile('Dataset/Test Set -Final.xlsx')
test=pd.read_excel(t)
mast=pd.ExcelFile('Dataset/master dataset.xlsx')
master=pd.read_excel(mast)

# %%
test.isnull().sum()
# Out:
# make                0
# model               0
# variant             1
# cc                  0
# seating_capacity    0
# fuel_type           0
# local_code          0
# dtype: int64

# %%
make_df1=df1.make
make_df2=df2.make
model_df1=df1.model
model_df2=df2.model
make_master=master.make.unique()
model_master=master.model.unique()

make_test=test.make
model_test=test.model

model_master
make_master
# Out:
# array(['ALFA ROMEO', 'ASTON MARTIN', 'AUDI', 'BENTLEY', 'BMW', 'MINI',
#        'CHEVROLET', 'CHRYSLER', 'DAEWOO', 'DATSUN', 'FERRARI', 'FIAT',
#        'FORCE', 'FORD', 'HINDUSTAN', 'HONDA', 'HUMMER', 'HYUNDAI',
#        'INFINITI', 'JAGUAR', 'LAMBORGHINI', 'LAND ROVER', 'Land Rover',
#        'MAHINDRA AND MAHINDRA', 'Mahindra And Mahindra',
#        'MAHINDRA RENAULT', 'MAHINDRA REVA', 'MARUTI SUZUKI', 'MASERATI',
#        'MERCEDES-BENZ', 'MITSUBISHI', 'NISSAN MOTORS', 'OPEL', 'PORSCHE',
#        'PREMIER', 'RENAULT', 'ROLLS ROYCE', 'SKODA', 'SSANGYONG', 'TATA',
#        'TOYOTA', 'VOLKSWAGEN', 'Volkswagen', 'VOLVO', 'ISUZU', 'JEEP',
#        'LEXUS', 'WILLYS INDIA', 'STANDARD HERALD', 'BAJAJ', 'CITROEN',
#        'DODGE', 'ICML', 'WOLSELEY', 'LANCHESTER', 'PLYMOUTH', 'CADILLAC',
#        'JM4 MOTORSPORTS', 'AUSTIN', 'BUICK', 'MCLAREN', 'STEYR', 'SAN',
#        'M G MOTORS', 'RELLY', 'PACKARD', 'ATVEA', 'MINERVA',
# ...

# %%
def similar(a, b):
    d = list(b.split())
    c = list(a.split())
    m = 0
    for j in d:
      if j == "PVT" or j == "MOTORS" or j == "LTD" or j == "MOTOR":
        continue
      for i in c:
        if i == "PVT" or i == "MOTORS" or i == "LTD" or i == "MOTOR":
          continue
        if (m<SequenceMatcher(None, i, j).ratio()):
          m = SequenceMatcher(None, i, j).ratio()
    return m

# count = 0
# for i in range(len(make_df1)):
#   if make_df1[i].upper() not in make_master:
#     MAX_SIM = 0.0
#     Max_j = -1
#     for j in range(len(make_master)):
#       make_df1[i] = make_df1[i].upper()
#       if MAX_SIM < similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_df1[i])))) ):
#         MAX_SIM = similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_df1[i])))))
#         Max_j = j
#     if MAX_SIM > 0.8:
#       #print("Old:" + make_df1[i].upper(), end = "\t")
#       make_df1[i] = make_master[Max_j]
#       #print("New:" + make_df1[i].upper())
    
# for i in range(len(make_df1)):
#   if make_df1[i] not in make_master:
#     count += 1
# print(count)

# %%
# count = 0
# for i in range(len(make_df2)):
#   make_df2[i] = make_df2[i].upper()
#   if make_df2[i]=="VOLKS WAGON":
#         make_df2[i] = "VOLKSWAGON"
#   if make_df2[i].upper() not in make_master:
#     MAX_SIM = 0.0
#     Max_j = -1
#     for j in range(len(make_master)):
#       make_df2[i] = make_df2[i].upper()
#       if MAX_SIM < similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_df2[i])))) ):
#         MAX_SIM = similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_df2[i])))))
#         Max_j = j
#     if MAX_SIM > 0.8:
#       #print("Old:" + make_df2[i].upper(), end = "\t")
#       make_df2[i] = make_master[Max_j]
#       #print("New:" + make_df2[i].upper())
#     else:
#         make_df2[i] = np.nan
    
# for i in range(len(make_df2)):
#   if make_df2[i] not in make_master:
#     count += 1
#     #print(make_df2[i])
# print(count)

# %%
df2
# Out:
#          make     model                       variant    cc  seating_capacity  \
# 0     HYUNDAI   SANTRO                       SANTRO L  1086                 5
# 1     HYUNDAI   ACCENT                     ACCENT GVS  1495                 5
# 2     HYUNDAI   ACCENT                     ACCENT GLX  1495                 5
# 3     HYUNDAI   ACCENT                    ACCENT VIVA  1599                 5
# 4     HYUNDAI   ACCENT                 ACCENT TORNADO  1599                 5
# ...       ...       ...                           ...   ...               ...
# 3359     JEEP  COMPASS    COMPASS LONGITUDE OPTION AT  1368                 5
# 3360   NISSAN  MAGNITE       MAGNITE 1.0 XV EXECUTIVE   999                 5
# 3361    SKODA   KODIAQ        KODIAQ 2.0 TSI STYLE AT  1984                 7
# 3362    SKODA   KODIAQ   KODIAQ 2.0 TSI SPORT LINE AT  1984                 7
# 3363    SKODA   KODIAQ      KODIAQ 2.0 TSI L AND K AT  1984                 7
#
#      fuel_type  local_code
# ...

# %%
# count = 0
# for i in range(len(model_df2)):
#   model_df2[i] = model_df2[i].upper()
#   if model_df2[i]=="VOLKS WAGON":
#         model_df2[i] = "VOLKSWAGON"
#   if model_df2[i].upper() not in model_master:
#     MAX_SIM = 0.0
#     Max_j = -1
#     for j in range(len(model_master)):
#       model_df2[i] = model_df2[i].upper()
#       if MAX_SIM < similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_df2[i])))) ):
#         MAX_SIM = similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_df2[i])))))
#         Max_j = j
#     if MAX_SIM > 0.8:
#       #print("Old:" + make_df2[i].upper(), end = "\t")
#       model_df2[i] = model_master[Max_j]
#       #print("New:" + make_df2[i].upper())
# #     else:
# #         model_df2[i] = np.nan
    
# for i in range(len(make_df2)):
#   if model_df2[i] not in model_master:
#     count += 1
#     #print(make_df2[i])
# print(count)

# %%
df2
# Out:
#          make     model                       variant    cc  seating_capacity  \
# 0     HYUNDAI   SANTRO                       SANTRO L  1086                 5
# 1     HYUNDAI   ACCENT                     ACCENT GVS  1495                 5
# 2     HYUNDAI   ACCENT                     ACCENT GLX  1495                 5
# 3     HYUNDAI   ACCENT                    ACCENT VIVA  1599                 5
# 4     HYUNDAI   ACCENT                 ACCENT TORNADO  1599                 5
# ...       ...       ...                           ...   ...               ...
# 3359     JEEP  COMPASS    COMPASS LONGITUDE OPTION AT  1368                 5
# 3360   NISSAN  MAGNITE       MAGNITE 1.0 XV EXECUTIVE   999                 5
# 3361    SKODA   KODIAQ        KODIAQ 2.0 TSI STYLE AT  1984                 7
# 3362    SKODA   KODIAQ   KODIAQ 2.0 TSI SPORT LINE AT  1984                 7
# 3363    SKODA   KODIAQ      KODIAQ 2.0 TSI L AND K AT  1984                 7
#
#      fuel_type  local_code
# ...

# %%
# count = 0
# for i in range(len(model_df1)):
#   model_df1[i] = model_df1[i].upper()
#   if model_df1[i]=="VOLKS WAGON":
#         model_df1[i] = "VOLKSWAGON"
#   if model_df1[i].upper() not in model_master:
#     MAX_SIM = 0.0
#     Max_j = -1
#     for j in range(len(model_master)):
#       model_df1[i] = model_df1[i].upper()
#       if MAX_SIM < similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_df1[i])))) ):
#         MAX_SIM = similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_df1[i])))))
#         Max_j = j
#     if MAX_SIM > 0.8:
#       #print("Old:" + make_df2[i].upper(), end = "\t")
#       model_df1[i] = model_master[Max_j]
#       #print("New:" + make_df2[i].upper())
# #     else:
# #         model_df2[i] = np.nan
    
# for i in range(len(make_df1)):
#   if model_df1[i] not in model_master:
#     count += 1
#     #print(make_df2[i])
# print(count)

# %%
df1
# Out:
#                  make      model                       variant    cc  \
# 0               HONDA       CR-V                        2.4 MT  2354
# 1               HONDA       CR-V                        2.4 MT  2354
# 2          VOLKSWAGEN       AMEO  1.5L TDI MT COMFORTLINE PLUS  1498
# 3                FORD       FIGO    1.2 TITANIUM SPORTS PETROL  1196
# 4         LAMBORGHINI  AVENTADOR                    S LP 740-4  6498
# ...               ...        ...                           ...   ...
# 5732  TATA MOTORS LTD      TIGOR                        XZ CNG  1199
# 5733  TATA MOTORS LTD      TIGOR                REVOTRON XZ(O)  1199
# 5734  TATA MOTORS LTD      TIGOR                   REVOTRON XT  1199
# 5735             FORD       IKON                      1.3 IRIS  1299
# 5736        MAHINDRA.    KUV 100                TRIP 5 STR CNG  1198
#
#       seating_capacity fuel_type  local_output
# 0                    5    PETROL         12623
# ...

# %%
df1=pd.DataFrame(df1[['make',	'model',	'variant','cc',	'seating_capacity'	,'fuel_type',	'local_output']])
df2=pd.DataFrame(df2[['make',	'model',	'variant','cc',	'seating_capacity'	,'fuel_type',	'local_code']])
df1.drop_duplicates(inplace=True)
df1.rename(columns={"local_output":"local_code"},inplace=True)
df12=pd.concat([df1,df2])

# %%
df12.reset_index(inplace=True,drop=True)

# %%
df12.head(12)
# Out:
#               make        model                       variant    cc  \
# 0            HONDA         CR-V                        2.4 MT  2354
# 1       VOLKSWAGEN         AMEO  1.5L TDI MT COMFORTLINE PLUS  1498
# 2             FORD         FIGO    1.2 TITANIUM SPORTS PETROL  1196
# 3      LAMBORGHINI    AVENTADOR                    S LP 740-4  6498
# 4            SKODA        RAPID        MONTE CARLO 1.6 MPI AT  1598
# 5            SKODA      OCTAVIA              STYLE AT 1.8 TSI  1798
# 6              BMW     3-SERIES            320D EDITION SPORT  1995
# 7           MARUTI        SWIFT                  LDI (DIESEL)  1248
# 8   GENERAL MOTORS       TAVERA                   B2 8 SEATER  2499
# 9    TOYOTA MOTORS  TOYOTA RAV4                           NaN  1998
# 10          MARUTI         ALTO                     K10 LX(O)   998
# 11             BMW     3-SERIES               330i SPORT LINE  1998
#
#     seating_capacity fuel_type  local_code
# ...

# %%
for i in range(len(df12)):
    if 'petrol' in  df12.fuel_type[i].lower():
        df12.fuel_type[i]='Petrol'
    elif 'diesel' in  df12.fuel_type[i].lower():
        df12.fuel_type[i]='Diesel'
    
    elif 'electric' in  df12.fuel_type[i].lower():
                df12.fuel_type[i]='Electric'
# Out:
# /tmp/ipykernel_20340/2951929330.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12.fuel_type[i]='Petrol'
# /tmp/ipykernel_20340/2951929330.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12.fuel_type[i]='Diesel'
# /tmp/ipykernel_20340/2951929330.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12.fuel_type[i]='Electric'

# %%
df12
# Out:
#              make      model                       variant    cc  \
# 0           HONDA       CR-V                        2.4 MT  2354
# 1      VOLKSWAGEN       AMEO  1.5L TDI MT COMFORTLINE PLUS  1498
# 2            FORD       FIGO    1.2 TITANIUM SPORTS PETROL  1196
# 3     LAMBORGHINI  AVENTADOR                    S LP 740-4  6498
# 4           SKODA      RAPID        MONTE CARLO 1.6 MPI AT  1598
# ...           ...        ...                           ...   ...
# 9073         JEEP   COMPASS    COMPASS LONGITUDE OPTION AT  1368
# 9074       NISSAN   MAGNITE       MAGNITE 1.0 XV EXECUTIVE   999
# 9075        SKODA    KODIAQ        KODIAQ 2.0 TSI STYLE AT  1984
# 9076        SKODA    KODIAQ   KODIAQ 2.0 TSI SPORT LINE AT  1984
# 9077        SKODA    KODIAQ      KODIAQ 2.0 TSI L AND K AT  1984
#
#       seating_capacity fuel_type  local_code
# 0                    5    Petrol       12623
# 1                    5    Diesel       36811
# 2                    5    Petrol       36819
# ...

# %%
df12.to_csv('df.csv')

# %%
df12[df12['make']=="MARUTI SUZUKI"]
# Out:
# Empty DataFrame
# Columns: [make, model, variant, cc, seating_capacity, fuel_type, local_code]
# Index: []

# %%
count = 0
for i in range(len(model_test)):
  model_test[i] = model_test[i].upper()
  if model_test[i]=="VOLKS WAGON":
        model_test[i] = "VOLKSWAGON"
  if model_test[i].upper() not in model_master:
    MAX_SIM = 0.0
    Max_j = -1
    for j in range(len(model_master)):
      model_test[i] = model_test[i].upper()
      if MAX_SIM < similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_test[i])))) ):
        MAX_SIM = similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(model_test[i])))))
        Max_j = j
    if MAX_SIM > 0.8:
      #print("Old:" + make_df2[i].upper(), end = "\t")
      model_df1[i] = model_master[Max_j]
      #print("New:" + make_df2[i].upper())
#     else:
#         model_df2[i] = np.nan
    
for i in range(len(make_test)):
  if model_test[i] not in model_master:
    count += 1
    #print(make_df2[i])
print(count)
# Out:
# /tmp/ipykernel_20340/2065896648.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_test[i] = model_test[i].upper()
# /tmp/ipykernel_20340/2065896648.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_test[i] = model_test[i].upper()
# /tmp/ipykernel_20340/2065896648.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_df1[i] = model_master[Max_j]
# 285

# %%
count = 0
for i in range(len(make_test)):
  if make_test[i].upper() not in make_master:
    MAX_SIM = 0.0
    Max_j = -1
    for j in range(len(make_master)):
      make_test[i] = make_test[i].upper()
      if MAX_SIM < similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_test[i])))) ):
        MAX_SIM = similar("".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_master[j])))) , "".join(list(map(lambda x: " " if ord(x) < ord('A') or ord(x) > ord('Z') else x, list(make_test[i])))))
        Max_j = j
    if MAX_SIM > 0.8:
      #print("Old:" + make_df1[i].upper(), end = "\t")
      make_test[i] = make_master[Max_j]
      #print("New:" + make_df1[i].upper())
    
for i in range(len(make_test)):
  if make_test[i] not in make_master:
    count += 1
print(count)
# Out:
# /tmp/ipykernel_20340/3585320605.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   make_test[i] = make_test[i].upper()
# /tmp/ipykernel_20340/3585320605.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   make_test[i] = make_master[Max_j]
# 680

# %%
test
# Out:
#                        make    model                   variant    cc  \
# 0     MAHINDRA AND MAHINDRA   BOLERO                   DI 8Str  2523
# 1                    Jaguar       XF                      R V8  5000
# 2                   Hyundai    XCENT          1.2 Prime T CRDI  1186
# 3             Maruti Suzuki  CELERIO           ZXI AT Optional   998
# 4                     Skoda   KUSHAQ          1.5 Style TSI MT  1498
# ...                     ...      ...                       ...   ...
# 1195          MERCEDES-BENZ      GLC         220 D PROGRESSIVE  2143
# 1196          MARUTI SUZUKI  S-CROSS                 1.5 DELTA  1462
# 1197                  SKODA  OCTAVIA    ELEGANCE 2.0 TDI CR AT  1968
# 1198                   AUDI  AUDI Q3           2.0 TDI QUATTRO  1968
# 1199                  SKODA    RAPID  1.5 TDI CR ELEGANCE PLUS  1498
#
#       seating_capacity fuel_type  local_code
# 0                    8    Diesel         512
# 1                    5    Petrol         459
# ...

# %%
test=pd.DataFrame(test[['make',	'model',	'variant','cc',	'seating_capacity'	,'fuel_type',	'local_code']])
for i in range(len(test)):
    if 'petrol' in  test.fuel_type[i].lower():
        test.fuel_type[i]='Petrol'
    elif 'diesel' in  test.fuel_type[i].lower():
        test.fuel_type[i]='Diesel'
    
    elif 'electric' in  test.fuel_type[i].lower():
                test.fuel_type[i]='Electric'
# Out:
# /tmp/ipykernel_20340/1708928812.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.fuel_type[i]='Diesel'
# /tmp/ipykernel_20340/1708928812.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.fuel_type[i]='Petrol'

# %%
test.reset_index(inplace=True,drop=True)

# %%
test
# Out:
#                        make    model                   variant    cc  \
# 0     MAHINDRA AND MAHINDRA   BOLERO                   DI 8Str  2523
# 1                    Jaguar       XF                      R V8  5000
# 2                   Hyundai    XCENT          1.2 Prime T CRDI  1186
# 3             Maruti Suzuki  CELERIO           ZXI AT Optional   998
# 4                     Skoda   KUSHAQ          1.5 Style TSI MT  1498
# ...                     ...      ...                       ...   ...
# 1195          MERCEDES-BENZ      GLC         220 D PROGRESSIVE  2143
# 1196          MARUTI SUZUKI  S-CROSS                 1.5 DELTA  1462
# 1197                  SKODA  OCTAVIA    ELEGANCE 2.0 TDI CR AT  1968
# 1198                   AUDI  AUDI Q3           2.0 TDI QUATTRO  1968
# 1199                  SKODA    RAPID  1.5 TDI CR ELEGANCE PLUS  1498
#
#       seating_capacity fuel_type  local_code
# 0                    8    Diesel         512
# 1                    5    Petrol         459
# ...

# %%
test.to_csv('test.csv')
